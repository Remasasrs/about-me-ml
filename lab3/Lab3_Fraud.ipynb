# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots look cleaner
sns.set()

# %%
df = pd.read_csv("creditcard.csv", engine="python", on_bad_lines="skip")
df.head()
# Out:
#    Time        V1        V2        V3        V4                   V5  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155   -0.338320769942518
# 1   0.0  1.191857  0.266151  0.166480  0.448154   0.0600176492822243
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780   -0.503198133318193
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291  -0.0103088796030823
# 4   2.0 -1.158233  0.877737  1.548718  0.403034   -0.407193377311653
#
#          V6        V7        V8        V9  ...       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3  1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4  0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount  Class
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# viewing the data types of columns
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5         object
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272904 entries, 0 to 272903
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    272904 non-null  float64
#  1   V1      272904 non-null  float64
#  2   V2      272904 non-null  float64
#  3   V3      272904 non-null  float64
#  4   V4      272904 non-null  float64
#  5   V5      272904 non-null  object
#  6   V6      272904 non-null  float64
#  7   V7      272904 non-null  float64
#  8   V8      272904 non-null  float64
#  9   V9      272903 non-null  float64
#  10  V10     272903 non-null  float64
#  11  V11     272903 non-null  float64
#  12  V12     272903 non-null  float64
#  13  V13     272903 non-null  float64
#  14  V14     272903 non-null  float64
#  15  V15     272903 non-null  float64
#  16  V16     272903 non-null  float64
#  17  V17     272903 non-null  float64
#  18  V18     272903 non-null  float64
#  19  V19     272902 non-null  float64
#  20  V20     272901 non-null  float64
#  21  V21     272901 non-null  float64
#  22  V22     272901 non-null  float64
#  23  V23     272900 non-null  float64
#  24  V24     272900 non-null  float64
#  25  V25     272900 non-null  float64
#  26  V26     272900 non-null  float64
#  27  V27     272900 non-null  float64
#  28  V28     272899 non-null  float64
#  29  Amount  272899 non-null  float64
#  30  Class   272899 non-null  float64
# dtypes: float64(30), object(1)
# memory usage: 64.5+ MB

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  272899.000000  272899.000000  272899.000000  272899.000000
# mean    97709.115508       0.011421      -0.005266      -0.024586
# std     46395.583734       1.948596       1.647793       1.484831
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     58348.000000      -0.919820      -0.603204      -0.931490
# 50%     89758.000000       0.021080       0.062023       0.147649
# 75%    140537.000000       1.340500       0.804243       1.001202
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V6             V7             V8  \
# count  272899.000000  272899.000000  272899.000000  272899.000000
# mean       -0.009370      -0.001088       0.006205      -0.004143
# std         1.415748       1.331615       1.224282       1.179309
# min        -5.683171     -26.160506     -43.557242     -73.216718
# 25%        -0.854918      -0.771008      -0.551893      -0.211041
# 50%        -0.029872      -0.277052       0.043791       0.021446
# 75%         0.725630       0.397163       0.575250       0.328807
# max        16.875344      73.301626     120.589494      18.709255
#
#                   V9            V10  ...            V21            V22  \
# count  272899.000000  272899.000000  ...  272899.000000  272899.000000
# mean       -0.003734       0.002072  ...       0.000912       0.005268
# std         1.092956       1.083331  ...       0.734022       0.727902
# min       -13.434066     -24.588262  ...     -34.830382     -10.933144
# 25%        -0.643906      -0.536360  ...      -0.228016      -0.540822
# 50%        -0.050478      -0.093064  ...      -0.027076       0.011445
# 75%         0.592566       0.453706  ...       0.189067       0.538908
# max        15.594995      23.745136  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  272899.000000  272899.000000  272899.000000  272899.000000
# mean        0.001882      -0.000434      -0.006593       0.000353
# std         0.627580       0.606491       0.523502       0.482650
# min       -44.807735      -2.824849     -10.295397      -2.604551
# 25%        -0.161079      -0.356106      -0.323764      -0.327015
# 50%        -0.008993       0.040175       0.006390      -0.050854
# 75%         0.151363       0.442737       0.345968       0.242404
# max        22.528412       4.584549       7.519589       3.517346
#
#                  V27            V28         Amount          Class
# count  272899.000000  272899.000000  272899.000000  272899.000000
# mean       -0.000794      -0.000419      88.468725       0.001671
# std         0.403911       0.332306     250.471793       0.040843
# min       -22.565679     -15.430084       0.000000       0.000000
# 25%        -0.071451      -0.053857       5.500000       0.000000
# 50%         0.000750       0.010145      21.990000       0.000000
# 75%         0.091253       0.078087      77.000000       0.000000
# max        31.612198      33.847808   25691.160000       1.000000
#
# [8 rows x 30 columns]

# %%
df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%     50%       75%       max
# Class
# 0.0    272443.0   88.409751  250.446813  0.0  5.52  22.000   76.9500  25691.16
# 1.0       456.0  123.703465  262.906990  0.0  1.00   7.805  111.8575   2125.87

# %%
#Check Missing Values
print(df.isna().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# checking duplicate rows
df.duplicated()[df.duplicated()==True]
# Out:
# 33        True
# 35        True
# 113       True
# 114       True
# 115       True
#           ...
# 271084    True
# 271580    True
# 271582    True
# 272288    True
# 272290    True
# Length: 1037, dtype: bool

# %%
# finding number of rows and columns

print("Shape (rows, columns): ", df.shape,"\n")

print("number of rows: ", df.shape[0])
print("number of columns: ", df.shape[1])
# Out:
# Shape (rows, columns):  (272899, 31)
#
# number of rows:  272899
# number of columns:  31

# %%
# Statistical summary
df.describe(include='all')
# Out:
#                  Time             V1             V2             V3  \
# count   272899.000000  272899.000000  272899.000000  272899.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     97709.115508       0.011421      -0.005266      -0.024586
# std      46395.583734       1.948596       1.647793       1.484831
# min          0.000000     -56.407510     -72.715728     -48.325589
# 25%      58348.000000      -0.919820      -0.603204      -0.931490
# 50%      89758.000000       0.021080       0.062023       0.147649
# 75%     140537.000000       1.340500       0.804243       1.001202
# max     172792.000000       2.454930      22.057729       9.382558
#
#                    V4                V5             V6             V7  \
# count   272899.000000            272899  272899.000000  272899.000000
# unique            NaN            264385            NaN            NaN
# top               NaN  2.46307225982454            NaN            NaN
# freq              NaN                77            NaN            NaN
# mean        -0.009370               NaN      -0.001088       0.006205
# std          1.415748               NaN       1.331615       1.224282
# min         -5.683171               NaN     -26.160506     -43.557242
# 25%         -0.854918               NaN      -0.771008      -0.551893
# 50%         -0.029872               NaN      -0.277052       0.043791
# 75%          0.725630               NaN       0.397163       0.575250
# max         16.875344               NaN      73.301626     120.589494
#
#                    V8             V9  ...            V21            V22  \
# count   272899.000000  272899.000000  ...  272899.000000  272899.000000
# unique            NaN            NaN  ...            NaN            NaN
# top               NaN            NaN  ...            NaN            NaN
# freq              NaN            NaN  ...            NaN            NaN
# mean        -0.004143      -0.003734  ...       0.000912       0.005268
# std          1.179309       1.092956  ...       0.734022       0.727902
# min        -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%         -0.211041      -0.643906  ...      -0.228016      -0.540822
# 50%          0.021446      -0.050478  ...      -0.027076       0.011445
# 75%          0.328807       0.592566  ...       0.189067       0.538908
# max         18.709255      15.594995  ...      27.202839      10.503090
#
#                   V23            V24            V25            V26  \
# count   272899.000000  272899.000000  272899.000000  272899.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.001882      -0.000434      -0.006593       0.000353
# std          0.627580       0.606491       0.523502       0.482650
# min        -44.807735      -2.824849     -10.295397      -2.604551
# 25%         -0.161079      -0.356106      -0.323764      -0.327015
# 50%         -0.008993       0.040175       0.006390      -0.050854
# 75%          0.151363       0.442737       0.345968       0.242404
# max         22.528412       4.584549       7.519589       3.517346
#
#                   V27            V28         Amount          Class
# count   272899.000000  272899.000000  272899.000000  272899.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        -0.000794      -0.000419      88.468725       0.001671
# std          0.403911       0.332306     250.471793       0.040843
# min        -22.565679     -15.430084       0.000000       0.000000
# 25%         -0.071451      -0.053857       5.500000       0.000000
# 50%          0.000750       0.010145      21.990000       0.000000
# 75%          0.091253       0.078087      77.000000       0.000000
# max         31.612198      33.847808   25691.160000       1.000000
#
# [11 rows x 31 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(df["Amount"], bins=50)
plt.title("Amount Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Class", y="Amount", data=df)
plt.title("Fraud vs Normal Transaction Amount")
plt.show()
